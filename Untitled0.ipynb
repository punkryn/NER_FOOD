# %%
# %cd /content/drive/My Drive/Colab Notebooks/HanBert-NER-master
# Out:
# /content/drive/My Drive/Colab Notebooks/HanBert-NER-master

# %%
# !python3 main.py --model_type hanbert \
                  --model_name_or_path HanBert-54kN-torch\
                  --do_train \
                  --do_eval
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python3 main.py  --do_train \
                  --do_eval

# %%
# %ls
# Out:
# data/                      main.py           sample_pred_in.txt
# data_loader.py             predict.py        tokenization_hanbert.py
# HanBert-54kN-torch/        __pycache__/      trainer.py
# HanBert-54kN-torch.tar.gz  README.md         Untitled0.ipynb
# LICENSE                    requirements.txt  utils.py

# %%
# !pip install transformers==2.7.0
# !pip install seqeval==0.0.12
# Out:
# ...
#      |████████████████████████████████| 552kB 16.7MB/s
# ...
#      |████████████████████████████████| 1.1MB 45.6MB/s
# ...
#      |████████████████████████████████| 133kB 57.1MB/s
# ...
#      |████████████████████████████████| 890kB 26.8MB/s
# ...
#      |████████████████████████████████| 3.7MB 49.6MB/s
# ...
#      |████████████████████████████████| 7.1MB 43.9MB/s
# ...
#      |████████████████████████████████| 71kB 10.1MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=4cd73d1af0ff2580e46730ce49be6e6ed35d2603454eb25dbfb18d4620a7558d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ERROR: botocore 1.19.34 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...

# %%
# !pip install TorchCRF
